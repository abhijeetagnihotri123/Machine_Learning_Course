# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# %ls
# Out:
# complaint.csv  question1.ipynb

# %%
df = pd.read_csv('complaint.csv')
df
# Out:
#      Ticket #                                 Customer Complaint        Date  \
# 0      250635                              Cable Internet Speeds  22-04-2015
# 1      223441       Payment disappear - service got disconnected  04-08-2015
# 2      242732                                  Speed and Service  18-04-2015
# 3      277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4      307175                 not working and no service to boot  26-05-2015
# ...       ...                                                ...         ...
# 2072   338192    Speed throttling, speeds not at promised output  06-12-2015
# 2073   213550                               Service Availability  04-02-2015
# 2074   318775                 Monthly Billing for Returned Modem  06-02-2015
# 2075   331188                            complaint about comcast  06-09-2015
# 2076   360489                    Extremely unsatisfied  customer  23-06-2015
#
#      Date_month_year         Time        Received Via        City     State  \
# 0          22-Apr-15   3:53:50 PM  Customer Care Call    Abingdon  Maryland
# 1          04-Aug-15  10:22:56 AM            Internet     Acworth   Georgia
# 2          18-Apr-15   9:55:47 AM            Internet     Acworth   Georgia
# 3          05-Jul-15  11:59:35 AM            Internet     Acworth   Georgia
# 4          26-May-15   1:25:26 PM            Internet     Acworth   Georgia
# ...              ...          ...                 ...         ...       ...
# 2072       06-Dec-15   6:35:59 PM  Customer Care Call   Yorkville  Illinois
# 2073       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2074       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2075       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2076       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone
# 0        21009  Closed                          No
# 1        30102  Closed                          No
# 2        30101  Closed                         Yes
# 3        30101    Open                         Yes
# 4        30101  Solved                          No
# ...        ...     ...                         ...
# 2072     60560    Open                         Yes
# 2073     32466  Closed                          No
# 2074     48197  Solved                          No
# 2075     48197  Solved                          No
# 2076     48197  Solved                          No
#
# [2077 rows x 11 columns]

# %%
aux_df = df
aux_df['#complaints']=[1]*2077
aux_df
# Out:
#      Ticket #                                 Customer Complaint        Date  \
# 0      250635                              Cable Internet Speeds  22-04-2015
# 1      223441       Payment disappear - service got disconnected  04-08-2015
# 2      242732                                  Speed and Service  18-04-2015
# 3      277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4      307175                 not working and no service to boot  26-05-2015
# ...       ...                                                ...         ...
# 2072   338192    Speed throttling, speeds not at promised output  06-12-2015
# 2073   213550                               Service Availability  04-02-2015
# 2074   318775                 Monthly Billing for Returned Modem  06-02-2015
# 2075   331188                            complaint about comcast  06-09-2015
# 2076   360489                    Extremely unsatisfied  customer  23-06-2015
#
#      Date_month_year         Time        Received Via        City     State  \
# 0          22-Apr-15   3:53:50 PM  Customer Care Call    Abingdon  Maryland
# 1          04-Aug-15  10:22:56 AM            Internet     Acworth   Georgia
# 2          18-Apr-15   9:55:47 AM            Internet     Acworth   Georgia
# 3          05-Jul-15  11:59:35 AM            Internet     Acworth   Georgia
# 4          26-May-15   1:25:26 PM            Internet     Acworth   Georgia
# ...              ...          ...                 ...         ...       ...
# 2072       06-Dec-15   6:35:59 PM  Customer Care Call   Yorkville  Illinois
# 2073       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2074       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2075       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2076       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone  #complaints
# 0        21009  Closed                          No            1
# 1        30102  Closed                          No            1
# 2        30101  Closed                         Yes            1
# 3        30101    Open                         Yes            1
# 4        30101  Solved                          No            1
# ...        ...     ...                         ...          ...
# 2072     60560    Open                         Yes            1
# 2073     32466  Closed                          No            1
# 2074     48197  Solved                          No            1
# 2075     48197  Solved                          No            1
# 2076     48197  Solved                          No            1
#
# [2077 rows x 12 columns]

# %%
#part 5 of question1 creating a data_frame to hold data about states
state_df = pd.DataFrame(columns = ['State','complaints'])
#freq_df = pd.DateFrame(columns = ['State','complaints'])
state_df['State'] = aux_df['State']
state_df['complaints'] = aux_df['#complaints']
f = state_df.groupby('State').complaints.sum()
#storing the names of the states
l = ['Alabama','Arizona','Arkansas','California','Colorado','Connecticut'             
,'Delaware'                 
,'District Of Columbia'     
,'District of Columbia'      
,'Florida'                 
,'Georgia'                 
,'Illinois'                
,'Indiana'                  
,'Iowa'                    
,'Kansas'                    
,'Kentucky'                  
,'Louisiana'                
,'Maine'                     
,'Maryland'                 
,'Massachusetts'            
,'Michigan'                
,'Minnesota'                
,'Mississippi'              
,'Missouri'                  
,'Montana'               
,'Nevada'                    
,'New Hampshire'            
,'New Jersey'               
,'New Mexico'               
,'New York'                  
,'North Carolina'            
,'Ohio'                      
,'Oregon'                   
,'Pennsylvania'            
,'South Carolina'           
,'Tennessee'               
,'Texas'                    
,'Utah'                     
,'Vermont'                   
,'Virginia'                 
,'Washington'               
,'West Virginia']
freq_df = pd.DataFrame()
freq_df['State'] = l
al = []
for val in f:
    al.append(val)
freq_df['complaints'] = al
#freq_df contains number of complaints per state
Max_complaints = freq_df['complaints'].max()
Min_complaints = freq_df['complaints'].min()
MX_STATE = freq_df[(freq_df['complaints'] == Max_complaints)]['State']
MN_STATE = freq_df[(freq_df['complaints'] == Min_complaints)]['State']
MX_STATE
# Out:
# 10    Georgia
# Name: State, dtype: object

# %%
MN_STATE #can be more than one
# Out:
# 8     District of Columbia
# 13                    Iowa
# 14                  Kansas
# 24                 Montana
# 25                  Nevada
# Name: State, dtype: object

# %%
#part 4 of question1
freq_df.plot.bar()

# %%
#part 6 of the question
df1 = aux_df[aux_df['Status'] == 'Open']
df1
# Out:
#      Ticket #                                 Customer Complaint        Date  \
# 3      277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 9      371214   Raising Prices and Not Being Available To Ask...  28-06-2015
# 12     339282   Violating Open Internet Rules by Blocking HBO...  13-06-2015
# 23     370538                        monopoly bundling practices  27-06-2015
# 24     270163                                    bait and switch  05-02-2015
# ...       ...                                                ...         ...
# 2017   367577       charge my own router as unreturned equipment  26-06-2015
# 2034   376295                              Slow internet service  30-06-2015
# 2051   339481                   Terrible internet service from    13-06-2015
# 2057   305166                                    comcst data cap  24-05-2015
# 2072   338192    Speed throttling, speeds not at promised output  06-12-2015
#
#      Date_month_year         Time        Received Via            City  \
# 3          05-Jul-15  11:59:35 AM            Internet         Acworth
# 9          28-Jun-15   6:46:31 PM  Customer Care Call         Alameda
# 12         13-Jun-15   4:03:18 PM            Internet     Albuquerque
# 23         27-Jun-15   9:04:34 PM            Internet      Alexandria
# 24         05-Feb-15   3:55:24 PM            Internet       Algonquin
# ...              ...          ...                 ...             ...
# 2017       26-Jun-15  10:07:45 AM  Customer Care Call  West Lafayette
# 2034       30-Jun-15  10:57:27 PM            Internet     White House
# 2051       13-Jun-15   7:14:02 PM  Customer Care Call      Woodbridge
# 2057       24-May-15  12:34:08 AM  Customer Care Call       Woodstock
# 2072       06-Dec-15   6:35:59 PM  Customer Care Call       Yorkville
#
#            State  Zip code Status Filing on Behalf of Someone  #complaints
# 3        Georgia     30101   Open                         Yes            1
# 9     California     94501   Open                         Yes            1
# 12    New Mexico     87105   Open                         Yes            1
# 23      Virginia     22304   Open                          No            1
# 24      Illinois     60102   Open                         Yes            1
# ...          ...       ...    ...                         ...          ...
# 2017     Indiana     47906   Open                          No            1
# 2034   Tennessee     37188   Open                          No            1
# 2051    Virginia     22191   Open                          No            1
# 2057     Georgia     30188   Open                         Yes            1
# 2072    Illinois     60560   Open                         Yes            1
#
# [338 rows x 12 columns]

# %%
state_df = pd.DataFrame(columns = ['State','complaints'])
state_df['State'] = df1['State']
state_df['complaints'] = df1['#complaints']
f = state_df.groupby('State').complaints.sum()
freq_df1 = pd.DataFrame()
l1 = ['Alabama','Arizona','California','Colorado','Connecticut','Delaware','District Of Columbia','Florida',                 
'Georgia',                 
'Illinois',                
'Indiana',              
'Maine',                    
'Maryland',                 
'Massachusetts',            
'Michigan',                
'Minnesota',                
'Mississippi',              
'New Hampshire',           
'New Jersey',              
'New Mexico',               
'Oregon',                   
'Pennsylvania',            
'South Carolina',           
'Tennessee',               
'Texas',                   
'Utah',                     
'Vermont',                  
'Virginia',                 
'Washington',              
'West Virginia']
freq_df1['State'] = l1
frac_list = []
al1 = []
for val in f:
    al1.append(val)
for i in range(len(al1)):
    val = al1[i]//al[i]
    frac_list.append(val)
freq_df1['State'] = l1
freq_df1['frac_list'] = frac_list
print(freq_df1['frac_list'].max())
print(freq_df1['frac_list'].min())
#frac_list
# Out:
# 34
# 0

# %%
#part 1 and 2 aux_df gets month and we use this dataframe to group cumulative 
def getMonth(s):
    return s.split("-")[1]

aux_df['month'] = aux_df['Date_month_year'].apply(lambda x: getMonth(x))
aux_df
# Out:
#      Ticket #                                 Customer Complaint        Date  \
# 0      250635                              Cable Internet Speeds  22-04-2015
# 1      223441       Payment disappear - service got disconnected  04-08-2015
# 2      242732                                  Speed and Service  18-04-2015
# 3      277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4      307175                 not working and no service to boot  26-05-2015
# ...       ...                                                ...         ...
# 2072   338192    Speed throttling, speeds not at promised output  06-12-2015
# 2073   213550                               Service Availability  04-02-2015
# 2074   318775                 Monthly Billing for Returned Modem  06-02-2015
# 2075   331188                            complaint about comcast  06-09-2015
# 2076   360489                    Extremely unsatisfied  customer  23-06-2015
#
#      Date_month_year         Time        Received Via        City     State  \
# 0          22-Apr-15   3:53:50 PM  Customer Care Call    Abingdon  Maryland
# 1          04-Aug-15  10:22:56 AM            Internet     Acworth   Georgia
# 2          18-Apr-15   9:55:47 AM            Internet     Acworth   Georgia
# 3          05-Jul-15  11:59:35 AM            Internet     Acworth   Georgia
# 4          26-May-15   1:25:26 PM            Internet     Acworth   Georgia
# ...              ...          ...                 ...         ...       ...
# 2072       06-Dec-15   6:35:59 PM  Customer Care Call   Yorkville  Illinois
# 2073       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2074       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2075       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2076       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone  #complaints month
# 0        21009  Closed                          No            1   Apr
# 1        30102  Closed                          No            1   Aug
# 2        30101  Closed                         Yes            1   Apr
# 3        30101    Open                         Yes            1   Jul
# 4        30101  Solved                          No            1   May
# ...        ...     ...                         ...          ...   ...
# 2072     60560    Open                         Yes            1   Dec
# 2073     32466  Closed                          No            1   Feb
# 2074     48197  Solved                          No            1   Feb
# 2075     48197  Solved                          No            1   Sep
# 2076     48197  Solved                          No            1   Jun
#
# [2077 rows x 13 columns]

# %%
monthly_df = pd.DataFrame()

# %%
monthly_df['month'] = aux_df['month']
monthly_df['complaints'] = aux_df['#complaints']
f = monthly_df.groupby('month').complaints.sum()
l = ['Apr','Aug','Dec','Feb','Jan','Jul','Jun','Mar','May','Nov','Oct','Sep']
f_df = pd.DataFrame()
f_df['month'] = l
f_df['frequencies'] = v
#f_df is the trend chart 
f_df
# Out:
#    month  frequencies
# 0    Apr          351
# 1    Aug           61
# 2    Dec           59
# 3    Feb           54
# 4    Jan           52
# 5    Jul           44
# 6    Jun          984
# 7    Mar           42
# 8    May          297
# 9    Nov           35
# 10   Oct           47
# 11   Sep           51

# %%
#part2
f_df.plot.bar()
