# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
#loading the data using pandas library
df = pd.read_csv('Mart.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
g = df.groupby('Store')
g

# %%
stores = g['Weekly_Sales'].max()
stores
# Out:
# Store
# 1     2387950.20
# 2     3436007.68
# 3      605990.41
# 4     3676388.98
# 5      507900.07
# 6     2727575.18
# 7     1059715.27
# 8     1511641.09
# 9      905324.68
# 10    3749057.69
# 11    2306265.36
# 12    1768249.89
# 13    3595903.20
# 14    3818686.45
# 15    1368318.17
# 16    1004730.69
# 17    1309226.79
# 18    2027507.15
# 19    2678206.42
# 20    3766687.43
# 21    1587257.78
# 22    1962445.04
# 23    2734277.10
# 24    2386015.75
# 25    1295391.19
# 26    1573982.47
# 27    3078162.08
# 28    2026026.39
# 29    1130926.79
# 30     519354.88
# 31    2068942.97
# 32    1959526.96
# 33     331173.51
# 34    1620748.25
# 35    1781866.98
# 36     489372.02
# 37     605791.46
# 38     499267.66
# 39    2554482.84
# 40    1648829.18
# 41    2263722.68
# 42     674919.45
# 43     725043.04
# 44     376233.89
# 45    1682862.03
# Name: Weekly_Sales, dtype: float64

# %%
#Part 1 output both the store with highest sale as well as the sale itself
c = 0
max_store_number = c
val = 0
for value in stores:
    c += 1
    if val < value:
        val = value
        max_store_number = c
print(val,max_store_number)
# Out:
# 3818686.45 14

# %%
#part 2 of the question 
# will have to redefine all the dataframes
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('Mart.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
g = df.groupby('Store')
g

# %%
#getting the standard deviations and then finding the maximum
standard_deviations = g['Weekly_Sales'].std()

# %%
#finding the maximum standard deviation and the store number corresponding to it part2 of question
c = 0
max_store_number = c
val = 0
for value in standard_deviations:
    c += 1
    if val < value:
        val = value
        max_store_number = c
print(val,max_store_number)
# Out:
# 317569.9494755081 14

# %%
g = df['Weekly_Sales']

# %%
#part 3 of question2
mean_sales = g.mean()
mean_sales
# Out:
# 1046964.8775617732

# %%
g = df[(df.Holiday_Flag == 1)]
g
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 31        1  10-09-2010    1507460.69             1        78.69       2.565
# 42        1  26-11-2010    1955624.11             1        64.52       2.735
# 47        1  31-12-2010    1367320.01             1        48.43       2.943
# 53        1  11-02-2011    1649614.93             1        36.39       3.022
# ...     ...         ...           ...           ...          ...         ...
# 6375     45  09-09-2011     746129.56             1        71.48       3.738
# 6386     45  25-11-2011    1170672.94             1        48.71       3.492
# 6391     45  30-12-2011     869403.63             1        37.79       3.389
# 6397     45  10-02-2012     803657.12             1        37.00       3.640
# 6427     45  07-09-2012     766512.66             1        75.70       3.911
#
#              CPI  Unemployment
# 1     211.242170         8.106
# 31    211.495190         7.787
# 42    211.748433         7.838
# 47    211.404932         7.838
# 53    212.936705         7.742
# ...          ...           ...
# 6375  186.673738         8.625
# 6386  188.350400         8.523
# 6391  189.062016         8.523
# 6397  189.707605         8.424
# 6427  191.577676         8.684
#
# [450 rows x 8 columns]

# %%
h = g['Weekly_Sales']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a59d3c6127ed> in <module>
# ----> 1 h = g['Weekly_Sales']
#
# NameError: name 'g' is not defined

# %%
#storing all dates of holydays in the list and outputing them according to the condition
holidays = []
for val in h:
    if val > mean_sales:
        dt = g[g.Weekly_Sales == val].Date
        holidays.append(dt)
holidays #holds the required answer
# Out:
# [1    12-02-2010
#  Name: Date, dtype: object,
#  31    10-09-2010
#  Name: Date, dtype: object,
#  42    26-11-2010
#  Name: Date, dtype: object,
#  47    31-12-2010
#  Name: Date, dtype: object,
#  53    11-02-2011
#  Name: Date, dtype: object,
#  83    09-09-2011
#  Name: Date, dtype: object,
#  94    25-11-2011
#  Name: Date, dtype: object,
#  99    30-12-2011
#  Name: Date, dtype: object,
#  105    10-02-2012
#  Name: Date, dtype: object,
#  135    07-09-2012
#  Name: Date, dtype: object,
#  144    12-02-2010
#  Name: Date, dtype: object,
#  174    10-09-2010
#  Name: Date, dtype: object,
#  185    26-11-2010
#  Name: Date, dtype: object,
#  190    31-12-2010
#  Name: Date, dtype: object,
#  196    11-02-2011
#  Name: Date, dtype: object,
#  226    09-09-2011
#  Name: Date, dtype: object,
#  237    25-11-2011
#  Name: Date, dtype: object,
#  242    30-12-2011
#  Name: Date, dtype: object,
#  248    10-02-2012
#  Name: Date, dtype: object,
#  278    07-09-2012
#  Name: Date, dtype: object,
#  430    12-02-2010
#  Name: Date, dtype: object,
#  460    10-09-2010
#  Name: Date, dtype: object,
#  471    26-11-2010
#  Name: Date, dtype: object,
#  476    31-12-2010
#  Name: Date, dtype: object,
#  482    11-02-2011
#  Name: Date, dtype: object,
#  512    09-09-2011
#  Name: Date, dtype: object,
#  523    25-11-2011
#  Name: Date, dtype: object,
#  528    30-12-2011
#  Name: Date, dtype: object,
#  534    10-02-2012
#  Name: Date, dtype: object,
#  564    07-09-2012
#  Name: Date, dtype: object,
#  716    12-02-2010
#  Name: Date, dtype: object,
#  746    10-09-2010
#  Name: Date, dtype: object,
#  757    26-11-2010
#  Name: Date, dtype: object,
#  762    31-12-2010
#  Name: Date, dtype: object,
#  768    11-02-2011
#  Name: Date, dtype: object,
#  798    09-09-2011
#  Name: Date, dtype: object,
#  809    25-11-2011
#  Name: Date, dtype: object,
#  814    30-12-2011
#  Name: Date, dtype: object,
#  820    10-02-2012
#  Name: Date, dtype: object,
#  850    07-09-2012
#  Name: Date, dtype: object,
#  1043    26-11-2010
#  Name: Date, dtype: object,
#  1095    25-11-2011
#  Name: Date, dtype: object,
#  1288    12-02-2010
#  Name: Date, dtype: object,
#  1318    10-09-2010
#  Name: Date, dtype: object,
#  1329    26-11-2010
#  Name: Date, dtype: object,
#  1334    31-12-2010
#  Name: Date, dtype: object,
#  1340    11-02-2011
#  Name: Date, dtype: object,
#  1370    09-09-2011
#  Name: Date, dtype: object,
#  1381    25-11-2011
#  Name: Date, dtype: object,
#  1386    30-12-2011
#  Name: Date, dtype: object,
#  1392    10-02-2012
#  Name: Date, dtype: object,
#  1422    07-09-2012
#  Name: Date, dtype: object,
#  1431    12-02-2010
#  Name: Date, dtype: object,
#  1461    10-09-2010
#  Name: Date, dtype: object,
#  1472    26-11-2010
#  Name: Date, dtype: object,
#  1477    31-12-2010
#  Name: Date, dtype: object,
#  1483    11-02-2011
#  Name: Date, dtype: object,
#  1513    09-09-2011
#  Name: Date, dtype: object,
#  1524    25-11-2011
#  Name: Date, dtype: object,
#  1529    30-12-2011
#  Name: Date, dtype: object,
#  1535    10-02-2012
#  Name: Date, dtype: object,
#  1565    07-09-2012
#  Name: Date, dtype: object,
#  1574    12-02-2010
#  Name: Date, dtype: object,
#  1615    26-11-2010
#  Name: Date, dtype: object,
#  1626    11-02-2011
#  Name: Date, dtype: object,
#  1667    25-11-2011
#  Name: Date, dtype: object,
#  1672    30-12-2011
#  Name: Date, dtype: object,
#  1678    10-02-2012
#  Name: Date, dtype: object,
#  1717    12-02-2010
#  Name: Date, dtype: object,
#  1747    10-09-2010
#  Name: Date, dtype: object,
#  1758    26-11-2010
#  Name: Date, dtype: object,
#  1763    31-12-2010
#  Name: Date, dtype: object,
#  1769    11-02-2011
#  Name: Date, dtype: object,
#  1799    09-09-2011
#  Name: Date, dtype: object,
#  1810    25-11-2011
#  Name: Date, dtype: object,
#  1815    30-12-2011
#  Name: Date, dtype: object,
#  1821    10-02-2012
#  Name: Date, dtype: object,
#  1851    07-09-2012
#  Name: Date, dtype: object,
#  1860    12-02-2010
#  Name: Date, dtype: object,
#  1890    10-09-2010
#  Name: Date, dtype: object,
#  1901    26-11-2010
#  Name: Date, dtype: object,
#  1906    31-12-2010
#  Name: Date, dtype: object,
#  1912    11-02-2011
#  Name: Date, dtype: object,
#  1942    09-09-2011
#  Name: Date, dtype: object,
#  1953    25-11-2011
#  Name: Date, dtype: object,
#  1958    30-12-2011
#  Name: Date, dtype: object,
#  1964    10-02-2012
#  Name: Date, dtype: object,
#  1994    07-09-2012
#  Name: Date, dtype: object,
#  2044    26-11-2010
#  Name: Date, dtype: object,
#  2096    25-11-2011
#  Name: Date, dtype: object,
#  2319    10-09-2010
#  Name: Date, dtype: object,
#  2371    09-09-2011
#  Name: Date, dtype: object,
#  2382    25-11-2011
#  Name: Date, dtype: object,
#  2423    07-09-2012
#  Name: Date, dtype: object,
#  2432    12-02-2010
#  Name: Date, dtype: object,
#  2473    26-11-2010
#  Name: Date, dtype: object,
#  2484    11-02-2011
#  Name: Date, dtype: object,
#  2525    25-11-2011
#  Name: Date, dtype: object,
#  2536    10-02-2012
#  Name: Date, dtype: object,
#  2566    07-09-2012
#  Name: Date, dtype: object,
#  2575    12-02-2010
#  Name: Date, dtype: object,
#  2605    10-09-2010
#  Name: Date, dtype: object,
#  2616    26-11-2010
#  Name: Date, dtype: object,
#  2621    31-12-2010
#  Name: Date, dtype: object,
#  2627    11-02-2011
#  Name: Date, dtype: object,
#  2657    09-09-2011
#  Name: Date, dtype: object,
#  2668    25-11-2011
#  Name: Date, dtype: object,
#  2673    30-12-2011
#  Name: Date, dtype: object,
#  2679    10-02-2012
#  Name: Date, dtype: object,
#  2709    07-09-2012
#  Name: Date, dtype: object,
#  2718    12-02-2010
#  Name: Date, dtype: object,
#  2748    10-09-2010
#  Name: Date, dtype: object,
#  2759    26-11-2010
#  Name: Date, dtype: object,
#  2764    31-12-2010
#  Name: Date, dtype: object,
#  2770    11-02-2011
#  Name: Date, dtype: object,
#  2800    09-09-2011
#  Name: Date, dtype: object,
#  2811    25-11-2011
#  Name: Date, dtype: object,
#  2816    30-12-2011
#  Name: Date, dtype: object,
#  2822    10-02-2012
#  Name: Date, dtype: object,
#  2852    07-09-2012
#  Name: Date, dtype: object,
#  2902    26-11-2010
#  Name: Date, dtype: object,
#  2954    25-11-2011
#  Name: Date, dtype: object,
#  3045    26-11-2010
#  Name: Date, dtype: object,
#  3097    25-11-2011
#  Name: Date, dtype: object,
#  3147    12-02-2010
#  Name: Date, dtype: object,
#  3177    10-09-2010
#  Name: Date, dtype: object,
#  3188    26-11-2010
#  Name: Date, dtype: object,
#  3193    31-12-2010
#  Name: Date, dtype: object,
#  3199    11-02-2011
#  Name: Date, dtype: object,
#  3229    09-09-2011
#  Name: Date, dtype: object,
#  3240    25-11-2011
#  Name: Date, dtype: object,
#  3245    30-12-2011
#  Name: Date, dtype: object,
#  3251    10-02-2012
#  Name: Date, dtype: object,
#  3281    07-09-2012
#  Name: Date, dtype: object,
#  3290    12-02-2010
#  Name: Date, dtype: object,
#  3320    10-09-2010
#  Name: Date, dtype: object,
#  3331    26-11-2010
#  Name: Date, dtype: object,
#  3336    31-12-2010
#  Name: Date, dtype: object,
#  3342    11-02-2011
#  Name: Date, dtype: object,
#  3372    09-09-2011
#  Name: Date, dtype: object,
#  3383    25-11-2011
#  Name: Date, dtype: object,
#  3388    30-12-2011
#  Name: Date, dtype: object,
#  3394    10-02-2012
#  Name: Date, dtype: object,
#  3424    07-09-2012
#  Name: Date, dtype: object,
#  3474    26-11-2010
#  Name: Date, dtype: object,
#  3526    25-11-2011
#  Name: Date, dtype: object,
#  3617    26-11-2010
#  Name: Date, dtype: object,
#  3658    09-09-2011
#  Name: Date, dtype: object,
#  3669    25-11-2011
#  Name: Date, dtype: object,
#  3680    10-02-2012
#  Name: Date, dtype: object,
#  3710    07-09-2012
#  Name: Date, dtype: object,
#  3719    12-02-2010
#  Name: Date, dtype: object,
#  3749    10-09-2010
#  Name: Date, dtype: object,
#  3760    26-11-2010
#  Name: Date, dtype: object,
#  3765    31-12-2010
#  Name: Date, dtype: object,
#  3771    11-02-2011
#  Name: Date, dtype: object,
#  3801    09-09-2011
#  Name: Date, dtype: object,
#  3812    25-11-2011
#  Name: Date, dtype: object,
#  3817    30-12-2011
#  Name: Date, dtype: object,
#  3823    10-02-2012
#  Name: Date, dtype: object,
#  3853    07-09-2012
#  Name: Date, dtype: object,
#  3862    12-02-2010
#  Name: Date, dtype: object,
#  3892    10-09-2010
#  Name: Date, dtype: object,
#  3903    26-11-2010
#  Name: Date, dtype: object,
#  3908    31-12-2010
#  Name: Date, dtype: object,
#  3914    11-02-2011
#  Name: Date, dtype: object,
#  3944    09-09-2011
#  Name: Date, dtype: object,
#  3955    25-11-2011
#  Name: Date, dtype: object,
#  3960    30-12-2011
#  Name: Date, dtype: object,
#  3966    10-02-2012
#  Name: Date, dtype: object,
#  3996    07-09-2012
#  Name: Date, dtype: object,
#  4291    12-02-2010
#  Name: Date, dtype: object,
#  4321    10-09-2010
#  Name: Date, dtype: object,
#  4332    26-11-2010
#  Name: Date, dtype: object,
#  4337    31-12-2010
#  Name: Date, dtype: object,
#  4343    11-02-2011
#  Name: Date, dtype: object,
#  4373    09-09-2011
#  Name: Date, dtype: object,
#  4384    25-11-2011
#  Name: Date, dtype: object,
#  4389    30-12-2011
#  Name: Date, dtype: object,
#  4395    10-02-2012
#  Name: Date, dtype: object,
#  4425    07-09-2012
#  Name: Date, dtype: object,
#  4434    12-02-2010
#  Name: Date, dtype: object,
#  4475    26-11-2010
#  Name: Date, dtype: object,
#  4486    11-02-2011
#  Name: Date, dtype: object,
#  4516    09-09-2011
#  Name: Date, dtype: object,
#  4527    25-11-2011
#  Name: Date, dtype: object,
#  4532    30-12-2011
#  Name: Date, dtype: object,
#  4538    10-02-2012
#  Name: Date, dtype: object,
#  4568    07-09-2012
#  Name: Date, dtype: object,
#  4761    26-11-2010
#  Name: Date, dtype: object,
#  4813    25-11-2011
#  Name: Date, dtype: object,
#  4824    10-02-2012
#  Name: Date, dtype: object,
#  4863    12-02-2010
#  Name: Date, dtype: object,
#  4904    26-11-2010
#  Name: Date, dtype: object,
#  4956    25-11-2011
#  Name: Date, dtype: object,
#  5435    12-02-2010
#  Name: Date, dtype: object,
#  5465    10-09-2010
#  Name: Date, dtype: object,
#  5476    26-11-2010
#  Name: Date, dtype: object,
#  5481    31-12-2010
#  Name: Date, dtype: object,
#  5487    11-02-2011
#  Name: Date, dtype: object,
#  5517    09-09-2011
#  Name: Date, dtype: object,
#  5528    25-11-2011
#  Name: Date, dtype: object,
#  5533    30-12-2011
#  Name: Date, dtype: object,
#  5539    10-02-2012
#  Name: Date, dtype: object,
#  5569    07-09-2012
#  Name: Date, dtype: object,
#  5619    26-11-2010
#  Name: Date, dtype: object,
#  5671    25-11-2011
#  Name: Date, dtype: object,
#  5712    07-09-2012
#  Name: Date, dtype: object,
#  5721    12-02-2010
#  Name: Date, dtype: object,
#  5751    10-09-2010
#  Name: Date, dtype: object,
#  5762    26-11-2010
#  Name: Date, dtype: object,
#  5773    11-02-2011
#  Name: Date, dtype: object,
#  5803    09-09-2011
#  Name: Date, dtype: object,
#  5814    25-11-2011
#  Name: Date, dtype: object,
#  5819    30-12-2011
#  Name: Date, dtype: object,
#  5825    10-02-2012
#  Name: Date, dtype: object,
#  5855    07-09-2012
#  Name: Date, dtype: object,
#  6334    26-11-2010
#  Name: Date, dtype: object,
#  6386    25-11-2011
#  Name: Date, dtype: object]

# %%
#part 4 of question2 extracting six months data manually and storing them in different data frames
#give a bar plot for yearly statics month wise
#this part is doudbt to be discussed with instructor
def getMonth(s):
    return s.split('-')[1]
def getYear(s):
    return s.split('-')[2]
df['Month_Number'] = df['Date'].apply(lambda x : getMonth(x))
df['Year_Number'] = df['Date'].apply(lambda x : getYear(x))
y1_df = pd.DataFrame()
y2_df = pd.DataFrame()
y3_df = pd.DataFrame()
y1_df['Weekly_Sales'] = df[df['Year_Number'] == '2010']['Weekly_Sales']
y1_df['Month_Number'] = df[df['Year_Number'] == '2010']['Month_Number']
y2_df['Month_Number'] = df[df['Year_Number'] == '2011']['Month_Number']
y2_df['Weekly_Sales'] = df[df['Year_Number'] == '2011']['Weekly_Sales']
y3_df['Weekly_Sales'] = df[df['Year_Number'] == '2012']['Weekly_Sales']
y3_df['Month_Number'] = df[df['Year_Number'] == '2012']['Month_Number']
y1_df.plot.bar()

# %%
y2_df.plot.bar()

# %%
y3_df.plot.bar()

# %%
#statistical model part
import datetime as dt
g = df[df['Store']==2]

# %%
reg = linear_model.LinearRegression()
new_df = g.drop(['Weekly_Sales','Holiday_Flag','Temperature','Store','Fuel_Price'],axis = 'columns')
new_df['Date'] = pd.to_datetime(new_df['Date'])
new_df['Date'] = pd.to_numeric(new_df['Date'])
new_df
# Out:
#                      Date         CPI  Unemployment
# 1     1291248000000000000  211.242170         8.106
# 31    1286582400000000000  211.495190         7.787
# 42    1290729600000000000  211.748433         7.838
# 47    1293753600000000000  211.404932         7.838
# 53    1320192000000000000  212.936705         7.742
# ...                   ...         ...           ...
# 6375  1315526400000000000  186.673738         8.625
# 6386  1322179200000000000  188.350400         8.523
# 6391  1325203200000000000  189.062016         8.523
# 6397  1349136000000000000  189.707605         8.424
# 6427  1341792000000000000  191.577676         8.684
#
# [450 rows x 3 columns]

# %%
weekly_sales = g['Weekly_Sales']
# Out:
# 143    2136989.46
# 144    2137809.50
# 145    2124451.54
# 146    1865097.27
# 147    1991013.13
#           ...
# 281    1746470.56
# 282    1998321.04
# 283    1900745.13
# 284    1847990.41
# 285    1834458.35
# Name: Weekly_Sales, Length: 143, dtype: float64

# %%
reg.fit(new_df,weekly_sales)
# Out:
# LinearRegression()

# %%
#CPI and Unemployment rates do not have any impact on the weekly sales
reg.coef_
# Out:
# array([-5.50235846e-13,  0.00000000e+00,  0.00000000e+00])
